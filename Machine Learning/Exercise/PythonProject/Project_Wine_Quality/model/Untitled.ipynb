# %%
import pandas as pd

# %%
df1 = pd.read_csv("./dataset/winequalityN.csv")
df1.head()
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white            7.0              0.27         0.36            20.7
# 1  white            6.3              0.30         0.34             1.6
# 2  white            8.1              0.28         0.40             6.9
# 3  white            7.2              0.23         0.32             8.5
# 4  white            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates  alcohol  quality
# 0       0.45      8.8        6
# 1       0.49      9.5        6
# ...

# %%
df1.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6487.000000       6489.000000  6494.000000     6495.000000
# mean        7.216579          0.339691     0.318722        5.444326
# std         1.296750          0.164649     0.145265        4.758125
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6495.000000          6497.000000           6497.000000  6497.000000
# mean      0.056042            30.525319            115.744574     0.994697
# std       0.035036            17.749400             56.521855     0.002999
# ...

# %%
df = df1.drop("type",axis="columns")
correlation = df.corr()
print(correlation["quality"].sort_values(ascending=False))
# Out:
# quality                 1.000000
# alcohol                 0.444319
# citric acid             0.085706
# free sulfur dioxide     0.055463
# sulphates               0.038729
# pH                      0.019366
# residual sugar         -0.036825
# total sulfur dioxide   -0.041385
# fixed acidity          -0.077031
# chlorides              -0.200886
# volatile acidity       -0.265953
# density                -0.305858
# Name: quality, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12,10))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm")
plt.show()

# %%
df2 = df1.drop(["free sulfur dioxide","pH","residual sugar","total sulfur dioxide","fixed acidity"],axis="columns")

# %%
df2.head()
# Out:
#     type  volatile acidity  citric acid  chlorides  density  sulphates  \
# 0  white              0.27         0.36      0.045   1.0010       0.45
# 1  white              0.30         0.34      0.049   0.9940       0.49
# 2  white              0.28         0.40      0.050   0.9951       0.44
# 3  white              0.23         0.32      0.058   0.9956       0.40
# 4  white              0.23         0.32      0.058   0.9956       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# 3      9.9        6
# 4      9.9        6

# %%
df2.shape
# Out:
# (6497, 8)

# %%
df2.isnull().sum()
# Out:
# type                0
# volatile acidity    8
# citric acid         3
# chlorides           2
# density             0
# sulphates           4
# alcohol             0
# quality             0
# dtype: int64

# %%
df3 = df2.dropna()
df3.isnull().sum()
# Out:
# type                0
# volatile acidity    0
# citric acid         0
# chlorides           0
# density             0
# sulphates           0
# alcohol             0
# quality             0
# dtype: int64

# %%
df3.shape
# Out:
# (6480, 8)

# %%
df3.head()
# Out:
#     type  volatile acidity  citric acid  chlorides  density  sulphates  \
# 0  white              0.27         0.36      0.045   1.0010       0.45
# 1  white              0.30         0.34      0.049   0.9940       0.49
# 2  white              0.28         0.40      0.050   0.9951       0.44
# 3  white              0.23         0.32      0.058   0.9956       0.40
# 4  white              0.23         0.32      0.058   0.9956       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# 3      9.9        6
# 4      9.9        6

# %%
df3.describe()
# Out:
#        volatile acidity  citric acid    chlorides      density    sulphates  \
# count       6480.000000  6480.000000  6480.000000  6480.000000  6480.000000
# mean           0.339553     0.318765     0.056039     0.994696     0.531199
# std            0.164661     0.145261     0.035060     0.003001     0.148799
# min            0.080000     0.000000     0.009000     0.987110     0.220000
# 25%            0.230000     0.250000     0.038000     0.992320     0.430000
# 50%            0.290000     0.310000     0.047000     0.994890     0.510000
# 75%            0.400000     0.390000     0.065000     0.996993     0.600000
# max            1.580000     1.660000     0.611000     1.038980     2.000000
#
#            alcohol      quality
# count  6480.000000  6480.000000
# mean     10.492458     5.818827
# std       1.192760     0.873307
# min       8.000000     3.000000
# 25%       9.500000     5.000000
# 50%      10.300000     6.000000
# 75%      11.300000     6.000000
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

columns = ['volatile acidity', 'citric acid', 'chlorides', 'density', 'sulphates', 'alcohol', 'quality']
for col in columns:
    sns.boxplot(x=df3[col])
    plt.title(f'Boxplot of {col}')
    plt.show()

# %%
def remove_outlier_iqr(df, columns):
    df_clean = df.copy()
    for col in columns:
        Q1 =  df_clean[col].quantile(0.25)
        Q3 =  df_clean[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5*IQR
        upper_bound = Q3 + 1.5*IQR
        df_clean = df_clean[(df_clean[col] >=lower_bound) & (df_clean[col] <= upper_bound)]

    return df_clean

df4 = remove_outlier_iqr(df3,columns)
df4.shape
# Out:
# (4962, 8)

# %%
df4.head()
# Out:
#     type  volatile acidity  citric acid  chlorides  density  sulphates  \
# 0  white              0.27         0.36      0.045   1.0010       0.45
# 1  white              0.30         0.34      0.049   0.9940       0.49
# 2  white              0.28         0.40      0.050   0.9951       0.44
# 3  white              0.23         0.32      0.058   0.9956       0.40
# 4  white              0.23         0.32      0.058   0.9956       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# 3      9.9        6
# 4      9.9        6

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df4['type'] = le.fit_transform(df4['type'])

# %%
df4
# Out:
#       type  volatile acidity  citric acid  chlorides  density  sulphates  \
# 0        1             0.270         0.36      0.045  1.00100       0.45
# 1        1             0.300         0.34      0.049  0.99400       0.49
# 2        1             0.280         0.40      0.050  0.99510       0.44
# 3        1             0.230         0.32      0.058  0.99560       0.40
# 4        1             0.230         0.32      0.058  0.99560       0.40
# ...    ...               ...          ...        ...      ...        ...
# 6490     0             0.510         0.13      0.076  0.99574       0.75
# 6491     0             0.620         0.08      0.068  0.99651       0.82
# 6494     0             0.510         0.13      0.076  0.99574       0.75
# 6495     0             0.645         0.12      0.075  0.99547       0.71
# 6496     0             0.310         0.47      0.067  0.99549       0.66
#
#       alcohol  quality
# 0         8.8        6
# 1         9.5        6
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

X = df4.drop("quality", axis= "columns")
y = df4["quality"]

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2)

scaler = StandardScaler()
X_trained_scaled =  scaler.fit_transform(X_train)
X_test_scaled =  scaler.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression

clf = LogisticRegression(max_iter=1000)
clf.fit(X_trained_scaled,y_train)
y_pred = clf.predict(X_test_scaled)

# %%
from sklearn.metrics import accuracy_score
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.5579053373615307

# %%
X_trained_scaled
# Out:
# array([[ 0.38871852,  0.05135336, -0.31286866, ..., -1.36535471,
#         -1.07861031,  0.67487279],
#        [ 0.38871852, -1.58576693,  0.17896266, ..., -0.15471584,
#          0.04922546, -1.27406767],
#        [-2.57255558,  0.14230448, -2.28019394, ...,  0.08395297,
#          1.69760082, -0.42670225],
#        ...,
#        [ 0.38871852, -0.26697559, -0.41123492, ..., -0.00943917,
#         -1.07861031, -0.08775609],
#        [ 0.38871852, -0.1305489 ,  0.96589277, ...,  1.74771667,
#          2.73868   , -1.27406767],
#        [ 0.38871852, -0.85815792,  1.65445662, ..., -0.18930552,
#         -0.21104433,  0.25119008]])

# %%
X_train
# Out:
#       type  volatile acidity  citric acid  chlorides  density  sulphates  \
# 4576     1             0.300         0.29      0.036  0.99040       0.38
# 33       1             0.120         0.34      0.045  0.99390       0.51
# 6392     0             0.310         0.09      0.066  0.99459       0.70
# 4447     1             0.380         0.29      0.035  0.98916       0.37
# 2657     1             0.140         0.42      0.050  0.99116       0.69
# ...    ...               ...          ...        ...      ...        ...
# 2914     1             0.140         0.38      0.041  0.99043       0.54
# 2167     1             0.190         0.30      0.053  0.99860       0.49
# 4079     1             0.265         0.28      0.052  0.99432       0.38
# 868      1             0.280         0.42      0.040  0.99940       0.82
# 1473     1             0.200         0.49      0.038  0.99380       0.48
#
#       alcohol
# 4576     11.3
# 33        9.0
# 6392     10.0
# 4447     12.5
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_trained_scaled,y_train)
y_predict = rf.predict(X_test_scaled)
print("Accuracy:", accuracy_score(y_test, y_predict))
# Out:
# Accuracy: 0.6737160120845922

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(clf,X_trained_scaled, y_train,cv=5, scoring = "accuracy")
scores
# Out:
# array([0.54911839, 0.55667506, 0.5465995 , 0.5465995 , 0.56368222])

# %%
scores = cross_val_score(rf,X_trained_scaled, y_train,cv=5, scoring = "accuracy")
scores
# Out:
# array([0.66624685, 0.67506297, 0.67128463, 0.66498741, 0.6443884 ])

# %%
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV

# %%
model_params = {
    'svm': {
        'model': SVC(gamma='auto'),
        'params' : {
            'C': [1,10,20],
            'kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear'),
        'params': {
            'C': [1,5,10]
        }
    }
}

# %%
scores = []

for model_name, mp in model_params.items():
    clf = GridSearchCV(mp["model"],mp["params"],cv=5, return_train_score=False)
    clf.fit(X_trained_scaled,y_train)
    scores.append({
        "model" : model_name,
        "best_score" : clf.best_score_,
        "best_params" : clf.best_params_
    })

df5 = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df5
# Out:
#                  model  best_score                 best_params
# 0                  svm    0.563871  {'C': 10, 'kernel': 'rbf'}
# 1        random_forest    0.637440        {'n_estimators': 10}
# 2  logistic_regression    0.550520                    {'C': 1}

# %%
scores = []

for model_name, mp in model_params.items():
    clf = RandomizedSearchCV(estimator=mp["model"],param_distributions=mp["params"],cv=5, n_iter=6,random_state=42)
    clf.fit(X_trained_scaled,y_train)
    scores.append({
        "model" : model_name,
        "best_score" : clf.best_score_,
        "best_params" : clf.best_params_
    })

df5 = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df5
# Out:
# C:\Users\niraj.meshram\AppData\Local\miniconda3\Lib\site-packages\sklearn\model_selection\_search.py:317: UserWarning: The total space of parameters 3 is smaller than n_iter=6. Running 3 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# C:\Users\niraj.meshram\AppData\Local\miniconda3\Lib\site-packages\sklearn\model_selection\_search.py:317: UserWarning: The total space of parameters 3 is smaller than n_iter=6. Running 3 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
#                  model  best_score                 best_params
# 0                  svm    0.563871  {'kernel': 'rbf', 'C': 10}
# 1        random_forest    0.633153        {'n_estimators': 10}
# 2  logistic_regression    0.550520                    {'C': 1}
