# %%
import pandas as pd
import seaborn as se

df = pd.read_csv("weight-height.csv")
df.head()
df.Height.describe()
se.histplot(df.Height,kde=True)
# Out:
# <Axes: xlabel='Height', ylabel='Count'>

# %%
mean = df.Height.mean()
mean
# Out:
# np.float64(66.367559754866)

# %%
std_deviation = df.Height.std()
std_deviation
# Out:
# np.float64(3.847528120795573)

# %%
mean - 3*std_deviation
# Out:
# np.float64(54.824975392479274)

# %%
mean + 3*std_deviation
# Out:
# np.float64(77.91014411725271)

# %%
df[df.Height<54.824975392479274]
# Out:
#       Gender     Height
# 6624  Female  54.616858
# 9285  Female  54.263133

# %%
df[df.Height>77.91014411725271]
# Out:
#      Gender     Height
# 994    Male  78.095867
# 1317   Male  78.462053
# 2014   Male  78.998742
# 3285   Male  78.528210
# 3757   Male  78.621374

# %%
df_no_outlier = df[(df.Height > 54.824975392479274) & (df.Height < 77.91014411725271)]
df_no_outlier
# Out:
#       Gender     Height
# 0       Male  73.847017
# 1       Male  68.781904
# 2       Male  74.110105
# 3       Male  71.730978
# 4       Male  69.881796
# ...      ...        ...
# 9995  Female  66.172652
# 9996  Female  67.067155
# 9997  Female  63.867992
# 9998  Female  69.034243
# 9999  Female  61.944246
#
# [9993 rows x 2 columns]

# %%
df_no_outlier.shape
# Out:
# (9993, 2)

# %%
df
# Out:
#       Gender     Height
# 0       Male  73.847017
# 1       Male  68.781904
# 2       Male  74.110105
# 3       Male  71.730978
# 4       Male  69.881796
# ...      ...        ...
# 9995  Female  66.172652
# 9996  Female  67.067155
# 9997  Female  63.867992
# 9998  Female  69.034243
# 9999  Female  61.944246
#
# [10000 rows x 2 columns]

# %%
df["Z_Score"] = ((df.Height-df.Height.mean())/df.Height.std())
df
# Out:
#       Gender     Height   Z_Score
# 0       Male  73.847017  1.943964
# 1       Male  68.781904  0.627505
# 2       Male  74.110105  2.012343
# 3       Male  71.730978  1.393991
# 4       Male  69.881796  0.913375
# ...      ...        ...       ...
# 9995  Female  66.172652 -0.050658
# 9996  Female  67.067155  0.181830
# 9997  Female  63.867992 -0.649655
# 9998  Female  69.034243  0.693090
# 9999  Female  61.944246 -1.149651
#
# [10000 rows x 3 columns]

# %%
df_outlier = df[(df["Z_Score"] > 3) | (df["Z_Score"] < -3)]
df_outlier
# Out:
#       Gender     Height   Z_Score
# 994     Male  78.095867  3.048271
# 1317    Male  78.462053  3.143445
# 2014    Male  78.998742  3.282934
# 3285    Male  78.528210  3.160640
# 3757    Male  78.621374  3.184854
# 6624  Female  54.616858 -3.054091
# 9285  Female  54.263133 -3.146027

# %%
df
# Out:
#       Gender     Height   Z_Score
# 0       Male  73.847017  1.943964
# 1       Male  68.781904  0.627505
# 2       Male  74.110105  2.012343
# 3       Male  71.730978  1.393991
# 4       Male  69.881796  0.913375
# ...      ...        ...       ...
# 9995  Female  66.172652 -0.050658
# 9996  Female  67.067155  0.181830
# 9997  Female  63.867992 -0.649655
# 9998  Female  69.034243  0.693090
# 9999  Female  61.944246 -1.149651
#
# [10000 rows x 3 columns]

# %%
df_outlier = df[(df["Z_Score"] < 3) & (df["Z_Score"] > -3)]
df_outlier
# Out:
#       Gender     Height   Z_Score
# 0       Male  73.847017  1.943964
# 1       Male  68.781904  0.627505
# 2       Male  74.110105  2.012343
# 3       Male  71.730978  1.393991
# 4       Male  69.881796  0.913375
# ...      ...        ...       ...
# 9995  Female  66.172652 -0.050658
# 9996  Female  67.067155  0.181830
# 9997  Female  63.867992 -0.649655
# 9998  Female  69.034243  0.693090
# 9999  Female  61.944246 -1.149651
#
# [9993 rows x 3 columns]
